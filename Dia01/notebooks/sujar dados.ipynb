# %%
library(tidyverse)
library(janitor)
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.5
# ✔ forcats   1.0.0     ✔ stringr   1.5.1
# ✔ ggplot2   3.5.2     ✔ tibble    3.3.0
# ✔ lubridate 1.9.4     ✔ tidyr     1.3.1
# ✔ purrr     1.1.0
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package to force all conflicts to become errors
#
# Attaching package: ‘janitor’
#
# The following objects are masked from ‘package:stats’:
#
#     chisq.test, fisher.test
# Warning message:
# package ‘janitor’ was built under R version 4.5.2

# %%
url <- "http://archive.ics.uci.edu/ml/machine-learning-databases/breast-cancer-wisconsin/wdbc.data"
wbcd_raw <- read.table(url, sep = ",", header = FALSE, stringsAsFactors = FALSE)
head(wbcd_raw)
# Out:
#         V1 V2    V3    V4     V5     V6      V7      V8     V9     V10    V11
# 1   842302  M 17.99 10.38 122.80 1001.0 0.11840 0.27760 0.3001 0.14710 0.2419
# 2   842517  M 20.57 17.77 132.90 1326.0 0.08474 0.07864 0.0869 0.07017 0.1812
# 3 84300903  M 19.69 21.25 130.00 1203.0 0.10960 0.15990 0.1974 0.12790 0.2069
# 4 84348301  M 11.42 20.38  77.58  386.1 0.14250 0.28390 0.2414 0.10520 0.2597
# 5 84358402  M 20.29 14.34 135.10 1297.0 0.10030 0.13280 0.1980 0.10430 0.1809
# 6   843786  M 12.45 15.70  82.57  477.1 0.12780 0.17000 0.1578 0.08089 0.2087
#       V12    V13    V14   V15    V16      V17     V18     V19     V20     V21
# 1 0.07871 1.0950 0.9053 8.589 153.40 0.006399 0.04904 0.05373 0.01587 0.03003
# 2 0.05667 0.5435 0.7339 3.398  74.08 0.005225 0.01308 0.01860 0.01340 0.01389
# 3 0.05999 0.7456 0.7869 4.585  94.03 0.006150 0.04006 0.03832 0.02058 0.02250
# 4 0.09744 0.4956 1.1560 3.445  27.23 0.009110 0.07458 0.05661 0.01867 0.05963
# 5 0.05883 0.7572 0.7813 5.438  94.44 0.011490 0.02461 0.05688 0.01885 0.01756
# 6 0.07613 0.3345 0.8902 2.217  27.19 0.007510 0.03345 0.03672 0.01137 0.02165
#        V22   V23   V24    V25    V26    V27    V28    V29    V30    V31     V32
# 1 0.006193 25.38 17.33 184.60 2019.0 0.1622 0.6656 0.7119 0.2654 0.4601 0.11890
# 2 0.003532 24.99 23.41 158.80 1956.0 0.1238 0.1866 0.2416 0.1860 0.2750 0.08902
# 3 0.004571 23.57 25.53 152.50 1709.0 0.1444 0.4245 0.4504 0.2430 0.3613 0.08758
# 4 0.009208 14.91 26.50  98.87  567.7 0.2098 0.8663 0.6869 0.2575 0.6638 0.17300
# 5 0.005115 22.54 16.67 152.20 1575.0 0.1374 0.2050 0.4000 0.1625 0.2364 0.07678
# 6 0.005082 15.47 23.75 103.40  741.6 0.1791 0.5249 0.5355 0.1741 0.3985 0.12440

# %% [markdown]
# Atribuimos nomes às colunas (conforme a documentação)

# %%
colnames(wbcd_raw) <- c(
  "ID", "diagnosis",
  paste0("radius ", c("mean", "SE", "worst")),
  paste0("texture ", c("mean", "SE", "worst")),
  paste0("perimeter_", c("mean", "SE", "worst")),
  paste0("area_", c("mean", "SE", "worst")),
  paste0("smoothness_", c("mean", "SE", "worst")),
  paste0("compactness_", c("mean", "SE", "worst")),
  paste0("Concavity_", c("mean", "SE", "worst")),
  paste0("concave_points_", c("mean", "SE", "worst")),
  paste0("Symmetry ", c("mean", "SE", "worst")),
  paste0("fractal_dim_", c("mean", "SE", "worst"))
)
head(wbcd_raw)
# Out:
#         ID diagnosis radius mean radius SE radius worst texture mean texture SE
# 1   842302         M       17.99     10.38       122.80       1001.0    0.11840
# 2   842517         M       20.57     17.77       132.90       1326.0    0.08474
# 3 84300903         M       19.69     21.25       130.00       1203.0    0.10960
# 4 84348301         M       11.42     20.38        77.58        386.1    0.14250
# 5 84358402         M       20.29     14.34       135.10       1297.0    0.10030
# 6   843786         M       12.45     15.70        82.57        477.1    0.12780
#   texture worst perimeter_mean perimeter_SE perimeter_worst area_mean area_SE
# 1       0.27760         0.3001      0.14710          0.2419   0.07871  1.0950
# 2       0.07864         0.0869      0.07017          0.1812   0.05667  0.5435
# 3       0.15990         0.1974      0.12790          0.2069   0.05999  0.7456
# 4       0.28390         0.2414      0.10520          0.2597   0.09744  0.4956
# 5       0.13280         0.1980      0.10430          0.1809   0.05883  0.7572
# 6       0.17000         0.1578      0.08089          0.2087   0.07613  0.3345
#   area_worst smoothness_mean smoothness_SE smoothness_worst compactness_mean
# 1     0.9053           8.589        153.40         0.006399          0.04904
# 2     0.7339           3.398         74.08         0.005225          0.01308
# 3     0.7869           4.585         94.03         0.006150          0.04006
# 4     1.1560           3.445         27.23         0.009110          0.07458
# 5     0.7813           5.438         94.44         0.011490          0.02461
# 6     0.8902           2.217         27.19         0.007510          0.03345
#   compactness_SE compactness_worst Concavity_mean Concavity_SE Concavity_worst
# 1        0.05373           0.01587        0.03003     0.006193           25.38
# 2        0.01860           0.01340        0.01389     0.003532           24.99
# 3        0.03832           0.02058        0.02250     0.004571           23.57
# 4        0.05661           0.01867        0.05963     0.009208           14.91
# 5        0.05688           0.01885        0.01756     0.005115           22.54
# 6        0.03672           0.01137        0.02165     0.005082           15.47
#   concave_points_mean concave_points_SE concave_points_worst Symmetry mean
# 1               17.33            184.60               2019.0        0.1622
# 2               23.41            158.80               1956.0        0.1238
# 3               25.53            152.50               1709.0        0.1444
# 4               26.50             98.87                567.7        0.2098
# 5               16.67            152.20               1575.0        0.1374
# 6               23.75            103.40                741.6        0.1791
#   Symmetry SE Symmetry worst fractal_dim_mean fractal_dim_SE fractal_dim_worst
# 1      0.6656         0.7119           0.2654         0.4601           0.11890
# 2      0.1866         0.2416           0.1860         0.2750           0.08902
# 3      0.4245         0.4504           0.2430         0.3613           0.08758
# 4      0.8663         0.6869           0.2575         0.6638           0.17300
# 5      0.2050         0.4000           0.1625         0.2364           0.07678
# 6      0.5249         0.5355           0.1741         0.3985           0.12440

# %% [markdown]
# Abaixo introduzimos problemas comuns.
#
# + Valores ausentes e codificação inconsistente: Substituimos alguns varoles por `N/A`.

# %%
set.seed(20251126)
wbcd_dirty <- wbcd_raw
# num_cols <- wbcd_dirty |> select(where(is.numeric)) |> names()
num_cols <- wbcd_raw |> select(ends_with("_mean")) |> names()
for(col in num_cols) {
  idx <- sample(seq_len(nrow(wbcd_dirty)), size = 0.05 * nrow(wbcd_dirty))
  wbcd_dirty[idx, col] <- "N/A"
}

# %% [markdown]
# + Inconsistência de digitação: Introduzimos problemas na caixa de alguns diagnósticos (M $\to$ m, B $\to$ b) e convenções usadas (B $\to$ Benign).

# %%
set.seed(20251126)
wbcd_dirty[sample(which(wbcd_dirty$diagnosis == "M"), 24), "diagnosis"] <- "m"
wbcd_dirty[sample(which(wbcd_dirty$diagnosis == "B"), 24), "diagnosis"] <- c("b", "Benign")

# %% [markdown]
# + Separador decimal incorreto (vírgula): Substituímos em 5% das células numéricas

# %%
set.seed(20251126)
wbcd_dirty[, num_cols] <- lapply(
  wbcd_dirty[, num_cols],
  function(x) {
    ifelse(
      runif(length(x)) < 0.05, 
      gsub("\\.", ",", as.character(x)), 
      as.character(x)
    )
  }
)

# %%
wbcd_dirty
# Out:
#          ID diagnosis radius mean radius SE radius worst texture mean
# 1    842302         M      17.990     10.38       122.80       1001.0
# 2    842517         M      20.570     17.77       132.90       1326.0
# 3  84300903         M      19.690     21.25       130.00       1203.0
# 4  84348301         M      11.420     20.38        77.58        386.1
# 5  84358402         M      20.290     14.34       135.10       1297.0
# 6    843786         M      12.450     15.70        82.57        477.1
# 7    844359         M      18.250     19.98       119.60       1040.0
# 8  84458202         M      13.710     20.83        90.20        577.9
# 9    844981         m      13.000     21.82        87.50        519.8
# 10 84501001         M      12.460     24.04        83.97        475.9
# 11   845636         M      16.020     23.24       102.70        797.8
# 12 84610002         M      15.780     17.89       103.60        781.0
# 13   846226         M      19.170     24.80       132.40       1123.0
# 14   846381         M      15.850     23.95       103.70        782.7
# 15 84667401         m      13.730     22.61        93.60        578.3
# 16 84799002         M      14.540     27.54        96.73        658.8
# 17   848406         M      14.680     20.13        94.74        684.5
# 18 84862001         M      16.130     20.68       108.10        798.8
# 19   849014         M      19.810     22.15       130.00       1260.0
# 20  8510426         B      13.540     14.36        87.46        566.3
# 21  8510653         B      13.080     15.71        85.63        520.0
# 22  8510824         B       9.504     12.44        60.34        273.9
# 23  8511133         M      15.340     14.26       102.50        704.4
# 24   851509         m      21.160     23.04       137.20       1404.0
# 25   852552         m      16.650     21.38       110.00        904.6
# 26   852631         M      17.140     16.40       116.00        912.7
# 27   852763         M      14.580     21.53        97.41        644.8
# 28   852781         M      18.610     20.25       122.10       1094.0
# 29   852973         M      15.300     25.27       102.40        732.4
# 30   853201         M      17.570     15.05       115.00        955.1
# 31   853401         M      18.630     25.11       124.80       1088.0
#    texture SE texture worst perimeter_mean perimeter_SE perimeter_worst
# 1     0.11840       0.27760         0.3001      0.14710          0.2419
# 2     0.08474       0.07864         0.0869      0.07017          0.1812
# 3     0.10960       0.15990         0.1974      0.12790          0.2069
# 4     0.14250       0.28390         0.2414      0.10520          0.2597
# 5     0.10030       0.13280          0.198      0.10430          0.1809
# 6     0.12780       0.17000         0.1578      0.08089          0.2087
# 7     0.09463       0.10900         0.1127      0.07400          0.1794
# 8     0.11890       0.16450        0,09366      0.05985          0.2196
# 9     0.12730       0.19320         0.1859      0.09353          0.2350
# 10    0.11860       0.23960         0.2273      0.08543          0.2030
# 11    0.08206       0.06669        0.03299      0.03323          0.1528
# 12    0.09710       0.12920        0.09954      0.06606          0.1842
# 13    0.09740       0.24580         0.2065      0.11180          0.2397
# 14    0.08401       0.10020        0.09938      0.05364          0.1847
# 15    0.11310       0.22930            N/A      0.08025          0.2069
# 16    0.11390       0.15950         0.1639      0.07364          0.2303
# 17    0.09867       0.07200        0,07395      0.05259          0.1586
# 18    0.11700       0.20220         0.1722      0.10280          0.2164
# 19    0.09831       0.10270         0.1479      0.09498          0.1582
# 20    0.09779       0.08129        0.06664      0.04781          0.1885
# 21    0.10750       0.12700            N/A      0.03110          0.1967
# 22    0.10240       0.06492        0.02956      0.02076          0.1815
# 23    0.10730       0.21350         0.2077      0.09756          0.2521
# 24    0.09428       0.10220         0,1097      0.08632          0.1769
# 25    0.11210       0.14570         0.1525      0.09170          0.1995
# 26    0.11860       0.22760         0.2229      0.14010          0.3040
# 27    0.10540       0.18680         0.1425      0.08783          0.2252
# 28    0.09440       0.10660          0.149      0.07731          0.1697
# 29    0.10820       0.16970         0.1683      0.08751          0.1926
# 30    0.09847       0.11570        0.09875      0.07953          0.1739
# 31    0.10640       0.18870         0.2319      0.12440          0.2183
#    area_mean area_SE area_worst smoothness_mean smoothness_SE smoothness_worst
# 1    0.07871  1.0950     0.9053           8.589        153.40         0.006399
# 2    0.05667  0.5435     0.7339           3.398         74.08         0.005225
# 3    0.05999  0.7456     0.7869           4.585         94.03         0.006150
# 4        N/A  0.4956     1.1560           3.445         27.23         0.009110
# 5    0.05883  0.7572     0.7813           5.438         94.44         0.011490
# 6    0.07613  0.3345     0.8902           2.217         27.19         0.007510
# 7    0.05742  0.4467     0.7732            3.18         53.91         0.004314
# 8        N/A  0.5835     1.3770           3.856         50.96         0.008805
# 9    0.07389  0.3063     1.0020           2.406         24.32         0.005731
# 10   0.08243  0.2976     1.5990           2.039         23.94         0.007149
# 11   0.05697  0.3795     1.1870           2.466         40.51         0.004029
# 12   0.06082  0.5058     0.9849             N/A         54.16         0.005771
# 13     0.078  0.9555     3.5680           11.07        116.20         0.003139
# 14   0.05338  0.4033     1.0780           2.903         36.58         0.009769
# 15       N/A  0.2121     1.1690           2.061         19.21         0.006429
# 16   0.07077  0.3700     1.0330           2.879         32.55         0.005607
# 17   0.05922  0.4727     1.2400           3.195         45.40         0.005718
# 18   0.07356  0.5692     1.0730           3.854         54.18         0.007026
# 19   0.05395  0.7582     1.0170           5.865        112.40         0.006494
# 20   0.05766  0.2699     0.7886             N/A         23.56         0.008462
# 21   0.06811  0.1852     0.7477           1.383         14.67         0.004097
# 22       N/A  0.2773     0.9768           1.909         15.70         0.009606
# 23   0.07032  0.4388     0.7096           3,384         44.91         0.006789
# 24   0.05278  0.6917     1.1270           4.303         93.99         0.004728
# 25    0.0633  0.8068     0.9017           5.455        102.60         0.006048
# 26   0.07413  1.0460     0.9760           7.276        111.40         0.008029
# 27   0.06924  0.2545     0.9832            2.11         21.05         0.004452
# 28   0.05699  0.8529     1.8490           5.632         93.54         0.010750
# 29    0.0654  0.4390     1.0120           3.498         43.50         0.005233
# 30   0.06149  0.6003     0.8225           4.655         61.10         0.005627
# 31   0.06197  0.8307     1.4660           5.574        105.00         0.006248
#    compactness_mean compactness_SE compactness_worst Concavity_mean
# 1           0.04904        0.05373          0.015870        0.03003
# 2           0.01308        0.01860          0.013400        0.01389
# 3           0.04006        0.03832          0.020580         0.0225
# 4           0.07458        0.05661          0.018670        0.05963
# 5           0.02461        0.05688          0.018850        0.01756
# 6           0.03345        0.03672          0.011370        0.02165
# 7           0.01382        0.02254          0.010390        0.01369
# 8           0.03029        0.02488          0.014480        0.01486
# 9           0.03502        0.03553          0.012260        0,02143
# 10          0.07217        0.07743          0.014320        0.01789
# 11         0.009269        0.01101          0.007591         0.0146
# 12          0.04061        0.02791          0.012820        0.02008
# 13          0.08297        0.08890          0.040900        0.04484
# 14          0.03126        0.05051          0.019920            N/A
# 15          0.05936        0.05501          0.016280            N/A
# 16           0.0424        0.04741          0.010900        0.01857
# 17          0,01162        0.01998          0.011090         0.0141
# 18          0.02501        0.03188          0.012970        0.01689
# 19          0.01893        0.03391          0.015210        0.01356
# 20           0.0146        0.02387          0.013150         0.0198
# 21          0.01898        0.01698          0.006490            N/A
# 22          0.01432        0.01985          0.014210        0.02027
# 23          0,05328        0.06446          0.022520        0.03672
# 24          0.01259        0.01715          0.010380        0.01083
# 25          0.01882        0.02741          0.011300        0,01468
# 26          0.03799        0.03732          0.023970        0.02308
# 27          0.03055        0.02681          0.013520            N/A
# 28          0.02722        0.05081          0.019110        0.02293
# 29          0.03057        0.03576          0.010830        0.01768
# 30          0.03033        0.03407          0.013540        0.01925
# 31          0.03374        0.05196          0.011580        0.02007
#    Concavity_SE Concavity_worst concave_points_mean concave_points_SE
# 1      0.006193           25.38               17.33            184.60
# 2      0.003532           24.99               23.41            158.80
# 3      0.004571           23.57               25.53            152.50
# 4      0.009208           14.91                26.5             98.87
# 5      0.005115           22.54               16.67            152.20
# 6      0.005082           15.47               23.75            103.40
# 7      0.002179           22.88               27.66            153.20
# 8      0.005412           17.06               28,14            110.60
# 9      0.003749           15.49               30.73            106.20
# 10     0.010080           15.09               40.68             97.65
# 11     0.003042           19.19               33.88            123.80
# 12     0.004144           20.42               27,28            136.50
# 13     0.012840           20.96               29.94            151.70
# 14     0.003002           16.84               27.66            112.00
# 15     0.008093           15.03               32.01            108.80
# 16     0.005466           17.46               37.13            124.10
# 17     0.002085           19.07               30.88            123.40
# 18     0.004142           20.96               31.48            136.80
# 19     0.001997           27.32               30.88            186.80
# 20     0.002300           15.11               19,26             99.70
# 21     0.002425           14.50               20.49             96.09
# 22     0.002968           10.23               15.66             65.13
# 23     0.004394           18.07               19.08            125.10
# 24     0.001987           29.17               35.59            188.00
# 25     0.002801           26.46               31,56            177.00
# 26     0.007444           22.25                21.4            152.40
# 27     0.003711           17.62               33.21            122.40
# 28     0.004217           21.31               27,26            139.90
# 29     0.002967           20.27               36.71            149.30
# 30     0.003742           20.01               19.52            134.90
# 31     0.004560           23.15               34.01            160.50
#    concave_points_worst Symmetry mean Symmetry SE Symmetry worst
# 1                2019.0        0.1622      0.6656        0.71190
# 2                1956.0        0.1238      0.1866        0.24160
# 3                1709.0        0.1444      0.4245        0.45040
# 4                 567.7        0.2098      0.8663        0.68690
# 5                1575.0        0.1374      0.2050        0.40000
# 6                 741.6        0.1791      0.5249        0.53550
# 7                1606.0        0.1442      0.2576        0.37840
# 8                 897.0        0.1654      0.3682        0.26780
# 9                 739.3        0.1703      0.5401        0.53900
# 10                711.4        0.1853      1.0580        1.10500
# 11               1150.0        0.1181      0.1551        0.14590
# 12               1299.0        0.1396      0.5609        0.39650
# 13               1332.0        0.1037      0.3903        0.36390
# 14                876.5        0.1131      0.1924        0.23220
# 15                697.7        0.1651      0.7725        0.69430
# 16                943.2        0.1678      0.6577        0.70260
# 17               1138.0        0.1464      0.1871        0.29140
# 18               1315.0        0.1789      0.4233        0.47840
# 19               2398.0        0.1512      0.3150        0.53720
# 20                711.2        0.1440      0.1773        0.23900
# 21                630.5        0.1312      0.2776        0.18900
# 22                314.9        0.1324      0.1148        0.08867
# 23                980.9        0.1390      0.5954        0.63050
# 24               2615.0        0.1401      0.2600        0.31550
# 25               2215.0        0.1805      0.3578        0.46950
# 26               1461.0        0.1545      0.3949        0.38530
# 27                896.9        0.1525      0.6643        0.55390
# 28               1403.0        0.1338      0.2117        0.34460
# 29               1269.0        0.1641      0.6110        0.63350
# 30               1227.0        0.1255      0.2812        0.24890
# 31               1670.0        0.1491      0.4257        0.61330
#    fractal_dim_mean fractal_dim_SE fractal_dim_worst
# 1            0,2654         0.4601           0.11890
# 2             0.186         0.2750           0.08902
# 3             0.243         0.3613           0.08758
# 4            0.2575         0.6638           0.17300
# 5            0.1625         0.2364           0.07678
# 6            0.1741         0.3985           0.12440
# 7            0,1932         0.3063           0.08368
# 8            0.1556         0.3196           0.11510
# 9             0.206         0.4378           0.10720
# 10              N/A         0.4366           0.20750
# 11          0.09975         0.2948           0.08452
# 12            0.181         0.3792           0.10480
# 13           0.1767         0.3176           0.10230
# 14           0.1119         0.2809           0.06287
# 15           0.2208         0.3596           0.14310
# 16           0.1712         0.4218           0.13410
# 17           0.1609         0.3029           0.08216
# 18           0.2073         0.3706           0.11420
# 19           0.2388         0.2768           0.07615
# 20              N/A         0.2977           0.07259
# 21          0.07283         0.3184           0.08183
# 22          0.06227         0.2450           0.07773
# 23           0.2393         0.4667           0.09946
# 24           0.2009         0.2822           0.07526
# 25           0.2095         0.3613           0.09564
# 26            0.255         0.4066           0.10590
# 27           0.2701         0.4264           0.12750
# 28            0.149         0.2341           0.07421
# 29              N/A         0.4027           0.09876
# 30           0.1456         0.2756           0.07919
# 31           0.1848         0.3444           0.09782
#  [ reached 'max' / getOption("max.print") -- omitted 538 rows ]

# %%
write.csv(wbcd_dirty, "wbcd_dirty.csv", row.names = FALSE, na = "")
